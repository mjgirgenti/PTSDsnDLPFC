# %%
import numpy as np
import pandas as pd
import pegasus as pg
import json
import os
import matplotlib.pyplot as plt 
from utils.plot_utils import *
from utils.utils import *
from matplotlib.backends.backend_pdf import PdfPages

# %% [markdown]
# # Number Males/Females per condition

# %%
meta = pd.read_csv('/gpfs/gibbs/pi/gerstein/jz435/ShareZhangLab/PTSD/supp_tables/111_RNA_ATAC_samples_meta.csv',sep='\t')

# %%
meta[meta.Condition=='PTSD'].Sex.value_counts()
# Out:
# Sex
# F    19
# M    17
# Name: count, dtype: int64

# %%
meta[meta.Condition=='MDD'].Sex.value_counts()
# Out:
# Sex
# M    18
# F    18
# Name: count, dtype: int64

# %%
meta[meta.Condition=='CON'].Sex.value_counts()
# Out:
# Sex
# M    21
# F    18
# Name: count, dtype: int64

# %% [markdown]
# # Extended Data Figure 1a: 111 RNA and ATAC metadata table

# %%
meta = pd.read_csv('/gpfs/gibbs/pi/gerstein/jz435/ShareZhangLab/PTSD/supp_tables/csvs/Supp_Table1_Sample_metadata.csv',sep='\t')

# %%
meta = meta[meta.Modality=='RNA/ATAC']

# %%
meta
# Out:
#      Unnamed: 0  Modality             Sample Region Condition Sex Race
# 0             0  RNA/ATAC  MS0007NN/MS0001HH  dlPFC       CON   F    W  \
# 1             1  RNA/ATAC  MS0008OO/MS0002II  dlPFC       CON   M    B
# 2             2  RNA/ATAC  MS0009PP/MS0003JJ  dlPFC       MDD   M    W
# 3             3  RNA/ATAC  MS0010QQ/MS0004KK  dlPFC      PTSD   M    W
# 4             4  RNA/ATAC  MS0011RR/MS0005LL  dlPFC       MDD   M    B
# ..          ...       ...                ...    ...       ...  ..  ...
# 106         106  RNA/ATAC  MS0214CC/MS0214WW  dlPFC      PTSD   M    W
# 107         107  RNA/ATAC  MS0214DD/MS0214XX  dlPFC       MDD   F    W
# 108         108  RNA/ATAC  MS0214EE/MS0214YY  dlPFC       MDD   M    W
# 109         109  RNA/ATAC  MS0214FF/MS0214ZZ  dlPFC       CON   M    W
# 110         110  RNA/ATAC  MS0214GG/MS0214AA  dlPFC      PTSD   F    W
#
#      AgeDeath  RIN   PMI Smoking Antidepressant
# 0        18.0  7.4  21.4       N              N
# 1        39.0  8.2  21.5       Y              N
# 2        54.0  9.2  16.4       N              Y
# 3        53.0  8.0  23.3       Y              N
# 4        69.0  6.4  38.0       Y              Y
# ..        ...  ...   ...     ...            ...
# 106      28.0  5.7  20.2       Y              N
# 107      54.0  8.9  19.2       Y              Y
# 108      67.0  7.2  15.3       N              Y
# 109      25.0  7.9  20.2       N              N
# 110      36.7  7.3  42.0       Y              Y
#
# [111 rows x 12 columns]

# %%
con = meta[meta.Condition=='CON']
mdd = meta[meta.Condition=='MDD']
ptsd = meta[meta.Condition=='PTSD']

# %%
sex_all = []
race_all = []
age_all = []
pmi_all = []
rin_all = []
smoking_all = []
anti_all = []

for data in [con,mdd,ptsd]:
    sex = round(data[data.Sex=='M'].shape[0]/data.shape[0],2)
    race = round(data[data.Race=='W'].shape[0]/data.shape[0],2)
    age = str(round(data.AgeDeath.describe()['mean'],2)) + ' ± ' + str(round(con['AgeDeath'].describe()['std'],2))
    pmi = str(round(data.PMI.describe()['mean'],2)) + ' ± ' + str(round(con['PMI'].describe()['std'],2))
    rin = str(round(data.RIN.describe()['mean'],2)) + ' ± ' + str(round(con['RIN'].describe()['std'],2))
    smoking = round(data[data.Smoking=='Y'].shape[0]/data.shape[0],2)
    anti = round(data[data.Antidepressant=='Y'].shape[0]/data.shape[0],2)
    sex_all.append(sex)
    race_all.append(race)
    age_all.append(age)
    pmi_all.append(pmi)
    rin_all.append(rin)
    smoking_all.append(smoking)
    anti_all.append(anti)

# %%
df = pd.DataFrame(data=[sex_all,race_all,age_all,pmi_all,rin_all,smoking_all,anti_all],
             columns=['CON (N=39)','MDD (N=36)','PTSD (N=36)'],
             index=['Sex (% Male)','Race (% Caucasian)','Age at Death (mean ± std)','PMI (mean ± std)','RIN (mean ± std)','Smoking (% Yes)','Antidepressant (% Yes)'])

# %%
pdf_table = []
pdf_table.append(df)

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['font.size'] = '16'
fig, ax =plt.subplots(figsize=(7,7))
ax.axis('tight')
ax.axis('off')
the_table = ax.table(cellText=df.values,colLabels=df.columns,rowLabels=df.index,loc='center')
the_table.scale(1,2)

# %% [markdown]
# # Extended Data Figure 1b: 25 Multiome metadata table

# %%
meta = pd.read_csv('/gpfs/gibbs/pi/gerstein/jz435/ShareZhangLab/PTSD/supp_tables/csvs/Supp_Table1_Sample_metadata.csv',sep='\t')

# %%
meta = meta[meta.Modality=='Multiome']

# %%
con = meta[meta.Condition=='CON']
mdd = meta[meta.Condition=='MDD']
ptsd = meta[meta.Condition=='PTSD']

# %%
sex_all = []
race_all = []
age_all = []
pmi_all = []
rin_all = []
smoking_all = []
anti_all = []

for data in [con,mdd,ptsd]:
    sex = round(data[data.Sex=='M'].shape[0]/data.shape[0],2)
    race = round(data[data.Race=='W'].shape[0]/data.shape[0],2)
    age = str(round(data.AgeDeath.describe()['mean'],2)) + ' ± ' + str(round(con['AgeDeath'].describe()['std'],2))
    pmi = str(round(data.PMI.describe()['mean'],2)) + ' ± ' + str(round(con['PMI'].describe()['std'],2))
    rin = str(round(data.RIN.describe()['mean'],2)) + ' ± ' + str(round(con['RIN'].describe()['std'],2))
    smoking = round(data[data.Smoking=='Y'].shape[0]/data.shape[0],2)
    anti = round(data[data.Antidepressant=='Y'].shape[0]/data.shape[0],2)
    sex_all.append(sex)
    race_all.append(race)
    age_all.append(age)
    pmi_all.append(pmi)
    rin_all.append(rin)
    smoking_all.append(smoking)
    anti_all.append(anti)

# %%
df = pd.DataFrame(data=[sex_all,race_all,age_all,pmi_all,rin_all,smoking_all,anti_all],
             columns=['CON (N=9)','MDD (N=4)','PTSD (N=12)'],
             index=['Sex (% Male)','Race (% Caucasian)','Age at Death (mean ± std)','PMI (mean ± std)','RIN (mean ± std)','Smoking (% Yes)','Antidepressant (% Yes)'])

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['font.size'] = '16'
fig, ax =plt.subplots(figsize=(7,7))
ax.axis('tight')
ax.axis('off')
the_table = ax.table(cellText=df.values,colLabels=df.columns,rowLabels=df.index,loc='center')
the_table.scale(1,2)
